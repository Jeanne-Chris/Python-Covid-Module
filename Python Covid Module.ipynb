# %% [markdown]
# ## Using Python Covid Module

# %%
from covid import Covid
import requests
import pydantic

covid = Covid(source="worldometers")

# %%
Phil = covid.get_status_by_country_name('Philippines')

data = {key : Phil[key]
        for key in Phil.keys() and {'confirmed', 'active', 'deaths', 'recovered'}}

print(data)
# Out:
# {'recovered': 604368, 'confirmed': 771497, 'active': 153809, 'deaths': 13320}

# %%
North_US = covid.get_status_by_country_name('north america')

data = {key : North_US[key]
        for key in North_US.keys() and {'confirmed', 'active', 'deaths', 'recovered'}}

print(data)
# Out:
# {'recovered': 27678788, 'confirmed': 35977454, 'active': 7476805, 'deaths': 821861}

# %% [markdown]
# Display the names of the countries

# %%
countries = covid.list_countries()
print(countries)
# Out:
# ['north america', 'south america', 'asia', 'europe', 'africa', 'oceania', '', 'world', 'usa', 'brazil', 'india', 'france', 'russia', 'uk', 'italy', 'turkey', 'spain', 'germany', 'colombia', 'poland', 'argentina', 'mexico', 'iran', 'ukraine', 'peru', 'south africa', 'czechia', 'indonesia', 'netherlands', 'chile', 'canada', 'romania', 'belgium', 'iraq', 'israel', 'portugal', 'sweden', 'philippines', 'pakistan', 'hungary', 'bangladesh', 'jordan', 'serbia', 'switzerland', 'austria', 'morocco', 'japan', 'lebanon', 'uae', 'saudi arabia', 'slovakia', 'panama', 'malaysia', 'bulgaria', 'ecuador', 'belarus', 'georgia', 'nepal', 'croatia', 'bolivia', 'greece', 'azerbaijan', 'tunisia', 'dominican republic', 'kazakhstan', 'palestine', 'ireland', 'kuwait', 'denmark', 'moldova', 'slovenia', 'lithuania', 'costa rica', 'paraguay', 'ethiopia', 'egypt', 'armenia', 'guatemala', 'honduras', 'qatar', 'bosnia and herzegovina', 'nigeria', 'venezuela', 'libya', 'oman', 'bahrain', 'myanmar', 'kenya', 'north macedonia', 'albania', 'algeria', 'estonia', 'uruguay', 's. korea', 'latvia', 'norway', 'sri lanka', 'montenegro', 'ghana', 'zambia', 'kyrgyzstan', 'uzbekistan', 'finland', 'cuba', 'mozambique', 'el salvador', 'luxembourg', 'singapore', 'cameroon', 'afghanistan', 'cyprus', 'namibia', 'ivory coast', 'uganda', 'botswana', 'jamaica', 'senegal', 'zimbabwe', 'malawi', 'sudan', 'australia', 'malta', 'thailand', 'drc', 'madagascar', 'maldives', 'angola', 'rwanda', 'guinea', 'gabon', 'mayotte', 'syria', 'french polynesia', 'mauritania', 'cabo verde', 'eswatini', 'french guiana', 'réunion', 'tajikistan', 'haiti', 'burkina faso', 'belize', 'andorra', 'guadeloupe', 'hong kong', 'somalia', 'lesotho', 'togo', 'guyana', 'mali', 'south sudan', 'congo', 'aruba', 'mongolia', 'bahamas', 'suriname', 'curaçao', 'martinique', 'djibouti', 'trinidad and tobago', 'benin', 'equatorial guinea', 'nicaragua', 'papua new guinea', 'iceland', 'gambia', 'car', 'niger', 'san marino', 'chad', 'yemen', 'gibraltar', 'saint lucia', 'seychelles', 'channel islands', 'sierra leone', 'comoros', 'guinea-bissau', 'barbados', 'eritrea', 'burundi', 'liechtenstein', 'vietnam', 'cambodia', 'new zealand', 'turks and caicos', 'monaco', 'sao tome and principe', 'sint maarten', 'liberia', 'st. vincent grenadines', 'saint martin', 'isle of man', 'caribbean netherlands', 'bermuda', 'antigua and barbuda', 'mauritius', 'taiwan', 'bhutan', 'st. barth', 'diamond princess', 'timor-leste', 'faeroe islands', 'tanzania', 'cayman islands', 'wallis and futuna', 'brunei', 'dominica', 'grenada', 'british virgin islands', 'new caledonia', 'fiji', 'falkland islands', 'laos', 'macao', 'saint kitts and nevis', 'greenland', 'vatican city', 'anguilla', 'saint pierre miquelon', 'montserrat', 'solomon islands', 'western sahara', 'ms zaandam', 'marshall islands', 'samoa', 'vanuatu', 'micronesia', 'china']

# %% [markdown]
# Get the COVID-19 related information for all the countries

# %%
covid.get_data()
# Out:
# [{'country': 'North America',
#   'confirmed': 35977454,
#   'new_cases': 7473,
#   'deaths': 821861,
#   'recovered': 27678788,
#   'active': 7476805,
#   'critical': 15401,
#   'new_deaths': 476,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': 'South America',
#   'confirmed': 21315538,
#   'new_cases': 916,
#   'deaths': 557137,
#   'recovered': 19001143,
#   'active': 1757258,
#   'critical': 20993,
#   'new_deaths': 23,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': 'Asia',
#   'confirmed': 28744086,
#   'new_cases': 54659,
#   'deaths': 429971,
#   'recovered': 26244667,
#   'active': 2069448,
#   'critical': 26259,
#   'new_deaths': 423,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': 'Europe',
#   'confirmed': 39956643,
#   'new_cases': 97439,
#   'deaths': 919181,
#   'recovered': 28206804,
#   'active': 10830658,
#   'critical': 31306,
#   'new_deaths': 2043,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': 'Africa',
#   'confirmed': 4275774,
#   'new_cases': 2035,
#   'deaths': 113467,
#   'recovered': 3838310,
#   'active': 323997,
#   'critical': 3013,
#   'new_deaths': 24,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': 'Oceania',
#   'confirmed': 57570,
#   'new_cases': 378,
#   'deaths': 1142,
#   'recovered': 34578,
#   'active': 21850,
#   'critical': 6,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': '0',
#   'confirmed': 721,
#   'new_cases': 0,
#   'deaths': 15,
#   'recovered': 706,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': 'World',
#   'confirmed': 130327786,
#   'new_cases': 162900,
#   'deaths': 2842774,
#   'recovered': 105004996,
#   'active': 22480016,
#   'critical': 96978,
#   'new_deaths': 2989,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('16720'),
#   'total_deaths_per_million': Decimal('364.7'),
#   'population': Decimal('0')},
#  {'country': 'USA',
#   'confirmed': 31246019,
#   'new_cases': 1380,
#   'deaths': 566616,
#   'recovered': 23754392,
#   'active': 6925011,
#   'critical': 8727,
#   'new_deaths': 5,
#   'total_tests': 405045223,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('93985'),
#   'total_deaths_per_million': Decimal('1704'),
#   'population': Decimal('332457943')},
#  {'country': 'Brazil',
#   'confirmed': 12842717,
#   'new_cases': 0,
#   'deaths': 325559,
#   'recovered': 11239099,
#   'active': 1278059,
#   'critical': 8318,
#   'new_deaths': 0,
#   'total_tests': 28600000,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('60099'),
#   'total_deaths_per_million': Decimal('1523'),
#   'population': Decimal('213691728')},
#  {'country': 'India',
#   'confirmed': 12303131,
#   'new_cases': 1021,
#   'deaths': 163428,
#   'recovered': 11525039,
#   'active': 614664,
#   'critical': 8944,
#   'new_deaths': 0,
#   'total_tests': 245912587,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('8850'),
#   'total_deaths_per_million': Decimal('118'),
#   'population': Decimal('1390160589')},
#  {'country': 'France',
#   'confirmed': 4695082,
#   'new_cases': 0,
#   'deaths': 95976,
#   'recovered': 296166,
#   'active': 4302940,
#   'critical': 5109,
#   'new_deaths': 0,
#   'total_tests': 64823784,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('71810'),
#   'total_deaths_per_million': Decimal('1468'),
#   'population': Decimal('65381957')},
#  {'country': 'Russia',
#   'confirmed': 4563056,
#   'new_cases': 8792,
#   'deaths': 99633,
#   'recovered': 4186251,
#   'active': 277172,
#   'critical': 2300,
#   'new_deaths': 400,
#   'total_tests': 120900000,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('31258'),
#   'total_deaths_per_million': Decimal('683'),
#   'population': Decimal('145981477')},
#  {'country': 'UK',
#   'confirmed': 4350266,
#   'new_cases': 0,
#   'deaths': 126764,
#   'recovered': 3860174,
#   'active': 363328,
#   'critical': 547,
#   'new_deaths': 0,
#   'total_tests': 127546869,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('63830'),
#   'total_deaths_per_million': Decimal('1860'),
#   'population': Decimal('68153448')},
#  {'country': 'Italy',
#   'confirmed': 3607083,
#   'new_cases': 0,
#   'deaths': 109847,
#   'recovered': 2933757,
#   'active': 563479,
#   'critical': 3681,
#   'new_deaths': 0,
#   'total_tests': 50258742,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('59725'),
#   'total_deaths_per_million': Decimal('1819'),
#   'population': Decimal('60394983')},
#  {'country': 'Turkey',
#   'confirmed': 3357988,
#   'new_cases': 0,
#   'deaths': 31713,
#   'recovered': 3035043,
#   'active': 291232,
#   'critical': 2135,
#   'new_deaths': 0,
#   'total_tests': 38821795,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('39497'),
#   'total_deaths_per_million': Decimal('373'),
#   'population': Decimal('85018143')},
#  {'country': 'Spain',
#   'confirmed': 3291394,
#   'new_cases': 0,
#   'deaths': 75541,
#   'recovered': 3054725,
#   'active': 161128,
#   'critical': 1843,
#   'new_deaths': 0,
#   'total_tests': 42707830,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('70376'),
#   'total_deaths_per_million': Decimal('1615'),
#   'population': Decimal('46768384')},
#  {'country': 'Germany',
#   'confirmed': 2854137,
#   'new_cases': 0,
#   'deaths': 77244,
#   'recovered': 2548200,
#   'active': 228693,
#   'critical': 3680,
#   'new_deaths': 0,
#   'total_tests': 50399177,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('33984'),
#   'total_deaths_per_million': Decimal('920'),
#   'population': Decimal('83985015')},
#  {'country': 'Colombia',
#   'confirmed': 2417826,
#   'new_cases': 0,
#   'deaths': 63614,
#   'recovered': 2292803,
#   'active': 61409,
#   'critical': 2603,
#   'new_deaths': 0,
#   'total_tests': 12790489,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('47141'),
#   'total_deaths_per_million': Decimal('1240'),
#   'population': Decimal('51288726')},
#  {'country': 'Poland',
#   'confirmed': 2387511,
#   'new_cases': 30546,
#   'deaths': 54165,
#   'recovered': 1911249,
#   'active': 422097,
#   'critical': 3157,
#   'new_deaths': 497,
#   'total_tests': 12246907,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('63136'),
#   'total_deaths_per_million': Decimal('1432'),
#   'population': Decimal('37815450')},
#  {'country': 'Argentina',
#   'confirmed': 2363251,
#   'new_cases': 0,
#   'deaths': 55941,
#   'recovered': 2112266,
#   'active': 195044,
#   'critical': 3639,
#   'new_deaths': 0,
#   'total_tests': 8932772,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('51932'),
#   'total_deaths_per_million': Decimal('1229'),
#   'population': Decimal('45506307')},
#  {'country': 'Mexico',
#   'confirmed': 2244268,
#   'new_cases': 5381,
#   'deaths': 203664,
#   'recovered': 1777697,
#   'active': 262907,
#   'critical': 4798,
#   'new_deaths': 454,
#   'total_tests': 6110815,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('17271'),
#   'total_deaths_per_million': Decimal('1567'),
#   'population': Decimal('129946482')},
#  {'country': 'Iran',
#   'confirmed': 1908974,
#   'new_cases': 11660,
#   'deaths': 62876,
#   'recovered': 1633949,
#   'active': 212149,
#   'critical': 4500,
#   'new_deaths': 117,
#   'total_tests': 12963778,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('22512'),
#   'total_deaths_per_million': Decimal('741'),
#   'population': Decimal('84796692')},
#  {'country': 'Ukraine',
#   'confirmed': 1711630,
#   'new_cases': 19893,
#   'deaths': 33679,
#   'recovered': 1333370,
#   'active': 344581,
#   'critical': 177,
#   'new_deaths': 433,
#   'total_tests': 8238849,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('39315'),
#   'total_deaths_per_million': Decimal('774'),
#   'population': Decimal('43535903')},
#  {'country': 'Peru',
#   'confirmed': 1561723,
#   'new_cases': 0,
#   'deaths': 52161,
#   'recovered': 1476782,
#   'active': 32780,
#   'critical': 2065,
#   'new_deaths': 0,
#   'total_tests': 9394499,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('46877'),
#   'total_deaths_per_million': Decimal('1566'),
#   'population': Decimal('33315068')},
#  {'country': 'South Africa',
#   'confirmed': 1549451,
#   'new_cases': 0,
#   'deaths': 52897,
#   'recovered': 1474826,
#   'active': 21728,
#   'critical': 546,
#   'new_deaths': 0,
#   'total_tests': 9912073,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('25881'),
#   'total_deaths_per_million': Decimal('884'),
#   'population': Decimal('59867781')},
#  {'country': 'Czechia',
#   'confirmed': 1545865,
#   'new_cases': 6207,
#   'deaths': 26765,
#   'recovered': 1374823,
#   'active': 144277,
#   'critical': 1563,
#   'new_deaths': 83,
#   'total_tests': 12937735,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('144151'),
#   'total_deaths_per_million': Decimal('2496'),
#   'population': Decimal('10723900')},
#  {'country': 'Indonesia',
#   'confirmed': 1523179,
#   'new_cases': 5325,
#   'deaths': 41151,
#   'recovered': 1361017,
#   'active': 121011,
#   'critical': 0,
#   'new_deaths': 97,
#   'total_tests': 12853599,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('5525'),
#   'total_deaths_per_million': Decimal('149'),
#   'population': Decimal('275688031')},
#  {'country': 'Netherlands',
#   'confirmed': 1280443,
#   'new_cases': 0,
#   'deaths': 16559,
#   'recovered': 0,
#   'active': 0,
#   'critical': 677,
#   'new_deaths': 0,
#   'total_tests': 10298103,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('74603'),
#   'total_deaths_per_million': Decimal('965'),
#   'population': Decimal('17163338')},
#  {'country': 'Chile',
#   'confirmed': 1003406,
#   'new_cases': 0,
#   'deaths': 23328,
#   'recovered': 936721,
#   'active': 43357,
#   'critical': 2729,
#   'new_deaths': 0,
#   'total_tests': 11278506,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('52155'),
#   'total_deaths_per_million': Decimal('1213'),
#   'population': Decimal('19239097')},
#  {'country': 'Canada',
#   'confirmed': 987918,
#   'new_cases': 0,
#   'deaths': 23002,
#   'recovered': 915348,
#   'active': 49568,
#   'critical': 704,
#   'new_deaths': 0,
#   'total_tests': 27770015,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('26005'),
#   'total_deaths_per_million': Decimal('605'),
#   'population': Decimal('37989974')},
#  {'country': 'Romania',
#   'confirmed': 964726,
#   'new_cases': 5808,
#   'deaths': 23819,
#   'recovered': 862137,
#   'active': 78770,
#   'critical': 1454,
#   'new_deaths': 145,
#   'total_tests': 7400084,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('50401'),
#   'total_deaths_per_million': Decimal('1244'),
#   'population': Decimal('19141028')},
#  {'country': 'Belgium',
#   'confirmed': 887920,
#   'new_cases': 5467,
#   'deaths': 23045,
#   'recovered': 57391,
#   'active': 807484,
#   'critical': 755,
#   'new_deaths': 29,
#   'total_tests': 11238361,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('76364'),
#   'total_deaths_per_million': Decimal('1982'),
#   'population': Decimal('11627463')},
#  {'country': 'Iraq',
#   'confirmed': 856939,
#   'new_cases': 0,
#   'deaths': 14360,
#   'recovered': 764096,
#   'active': 78483,
#   'critical': 471,
#   'new_deaths': 0,
#   'total_tests': 8078977,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('20955'),
#   'total_deaths_per_million': Decimal('351'),
#   'population': Decimal('40894377')},
#  {'country': 'Israel',
#   'confirmed': 833707,
#   'new_cases': 251,
#   'deaths': 6220,
#   'recovered': 820906,
#   'active': 6581,
#   'critical': 368,
#   'new_deaths': 0,
#   'total_tests': 13576884,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('90644'),
#   'total_deaths_per_million': Decimal('676'),
#   'population': Decimal('9197590')},
#  {'country': 'Portugal',
#   'confirmed': 822314,
#   'new_cases': 0,
#   'deaths': 16859,
#   'recovered': 778912,
#   'active': 26543,
#   'critical': 129,
#   'new_deaths': 0,
#   'total_tests': 9101428,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('80822'),
#   'total_deaths_per_million': Decimal('1657'),
#   'population': Decimal('10174344')},
#  {'country': 'Sweden',
#   'confirmed': 813191,
#   'new_cases': 0,
#   'deaths': 13498,
#   'recovered': 0,
#   'active': 0,
#   'critical': 319,
#   'new_deaths': 0,
#   'total_tests': 7201692,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('80145'),
#   'total_deaths_per_million': Decimal('1330'),
#   'population': Decimal('10146474')},
#  {'country': 'Philippines',
#   'confirmed': 771497,
#   'new_cases': 15310,
#   'deaths': 13320,
#   'recovered': 604368,
#   'active': 153809,
#   'critical': 785,
#   'new_deaths': 17,
#   'total_tests': 10249771,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('6971'),
#   'total_deaths_per_million': Decimal('120'),
#   'population': Decimal('110671238')},
#  {'country': 'Pakistan',
#   'confirmed': 678165,
#   'new_cases': 5234,
#   'deaths': 14613,
#   'recovered': 607205,
#   'active': 56347,
#   'critical': 3384,
#   'new_deaths': 83,
#   'total_tests': 10297544,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3026'),
#   'total_deaths_per_million': Decimal('65'),
#   'population': Decimal('224089566')},
#  {'country': 'Hungary',
#   'confirmed': 670776,
#   'new_cases': 9055,
#   'deaths': 21262,
#   'recovered': 413370,
#   'active': 236144,
#   'critical': 1467,
#   'new_deaths': 267,
#   'total_tests': 4689589,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('69569'),
#   'total_deaths_per_million': Decimal('2205'),
#   'population': Decimal('9641901')},
#  {'country': 'Bangladesh',
#   'confirmed': 624594,
#   'new_cases': 6830,
#   'deaths': 9155,
#   'recovered': 547411,
#   'active': 68028,
#   'critical': 0,
#   'new_deaths': 50,
#   'total_tests': 4728113,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3764'),
#   'total_deaths_per_million': Decimal('55'),
#   'population': Decimal('165917524')},
#  {'country': 'Jordan',
#   'confirmed': 618059,
#   'new_cases': 0,
#   'deaths': 6940,
#   'recovered': 520498,
#   'active': 90621,
#   'critical': 729,
#   'new_deaths': 0,
#   'total_tests': 5966411,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('60129'),
#   'total_deaths_per_million': Decimal('675'),
#   'population': Decimal('10278953')},
#  {'country': 'Serbia',
#   'confirmed': 605406,
#   'new_cases': 0,
#   'deaths': 5345,
#   'recovered': 506743,
#   'active': 93318,
#   'critical': 291,
#   'new_deaths': 0,
#   'total_tests': 3441136,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('69500'),
#   'total_deaths_per_million': Decimal('614'),
#   'population': Decimal('8710886')},
#  {'country': 'Switzerland',
#   'confirmed': 603092,
#   'new_cases': 0,
#   'deaths': 10350,
#   'recovered': 548375,
#   'active': 44367,
#   'critical': 159,
#   'new_deaths': 0,
#   'total_tests': 6069595,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('69305'),
#   'total_deaths_per_million': Decimal('1189'),
#   'population': Decimal('8702049')},
#  {'country': 'Austria',
#   'confirmed': 552729,
#   'new_cases': 3137,
#   'deaths': 9397,
#   'recovered': 506675,
#   'active': 36657,
#   'critical': 535,
#   'new_deaths': 29,
#   'total_tests': 24086423,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('61109'),
#   'total_deaths_per_million': Decimal('1039'),
#   'population': Decimal('9044930')},
#  {'country': 'Morocco',
#   'confirmed': 496676,
#   'new_cases': 0,
#   'deaths': 8825,
#   'recovered': 483711,
#   'active': 4140,
#   'critical': 235,
#   'new_deaths': 0,
#   'total_tests': 5982757,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('13338'),
#   'total_deaths_per_million': Decimal('237'),
#   'population': Decimal('37237772')},
#  {'country': 'Japan',
#   'confirmed': 474773,
#   'new_cases': 0,
#   'deaths': 9162,
#   'recovered': 446416,
#   'active': 19195,
#   'critical': 380,
#   'new_deaths': 0,
#   'total_tests': 9873913,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3763'),
#   'total_deaths_per_million': Decimal('73'),
#   'population': Decimal('126185196')},
#  {'country': 'Lebanon',
#   'confirmed': 471962,
#   'new_cases': 0,
#   'deaths': 6286,
#   'recovered': 373833,
#   'active': 91843,
#   'critical': 952,
#   'new_deaths': 0,
#   'total_tests': 3581760,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('69381'),
#   'total_deaths_per_million': Decimal('924'),
#   'population': Decimal('6802440')},
#  {'country': 'UAE',
#   'confirmed': 465939,
#   'new_cases': 2180,
#   'deaths': 1502,
#   'recovered': 450111,
#   'active': 14326,
#   'critical': 0,
#   'new_deaths': 3,
#   'total_tests': 38080645,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('46688'),
#   'total_deaths_per_million': Decimal('151'),
#   'population': Decimal('9979768')},
#  {'country': 'Saudi Arabia',
#   'confirmed': 390597,
#   'new_cases': 0,
#   'deaths': 6676,
#   'recovered': 378469,
#   'active': 5452,
#   'critical': 699,
#   'new_deaths': 0,
#   'total_tests': 15184311,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('11091'),
#   'total_deaths_per_million': Decimal('190'),
#   'population': Decimal('35218720')},
#  {'country': 'Slovakia',
#   'confirmed': 363874,
#   'new_cases': 1385,
#   'deaths': 9877,
#   'recovered': 255300,
#   'active': 98697,
#   'critical': 582,
#   'new_deaths': 87,
#   'total_tests': 2373463,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('66624'),
#   'total_deaths_per_million': Decimal('1808'),
#   'population': Decimal('5461629')},
#  {'country': 'Panama',
#   'confirmed': 355499,
#   'new_cases': 0,
#   'deaths': 6119,
#   'recovered': 344327,
#   'active': 5053,
#   'critical': 105,
#   'new_deaths': 0,
#   'total_tests': 2164688,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('81434'),
#   'total_deaths_per_million': Decimal('1402'),
#   'population': Decimal('4365482')},
#  {'country': 'Malaysia',
#   'confirmed': 347972,
#   'new_cases': 1294,
#   'deaths': 1283,
#   'recovered': 332443,
#   'active': 14246,
#   'critical': 168,
#   'new_deaths': 5,
#   'total_tests': 7711350,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('10649'),
#   'total_deaths_per_million': Decimal('39'),
#   'population': Decimal('32676024')},
#  {'country': 'Bulgaria',
#   'confirmed': 346327,
#   'new_cases': 0,
#   'deaths': 13313,
#   'recovered': 262095,
#   'active': 70919,
#   'critical': 747,
#   'new_deaths': 0,
#   'total_tests': 2134815,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('50127'),
#   'total_deaths_per_million': Decimal('1927'),
#   'population': Decimal('6909035')},
#  {'country': 'Ecuador',
#   'confirmed': 330388,
#   'new_cases': 0,
#   'deaths': 16877,
#   'recovered': 281684,
#   'active': 31827,
#   'critical': 562,
#   'new_deaths': 0,
#   'total_tests': 1147695,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('18516'),
#   'total_deaths_per_million': Decimal('946'),
#   'population': Decimal('17843138')},
#  {'country': 'Belarus',
#   'confirmed': 323043,
#   'new_cases': 0,
#   'deaths': 2257,
#   'recovered': 313628,
#   'active': 7158,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 5388505,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('34195'),
#   'total_deaths_per_million': Decimal('239'),
#   'population': Decimal('9446987')},
#  {'country': 'Georgia',
#   'confirmed': 282789,
#   'new_cases': 529,
#   'deaths': 3798,
#   'recovered': 273930,
#   'active': 5061,
#   'critical': 0,
#   'new_deaths': 13,
#   'total_tests': 3443156,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('70992'),
#   'total_deaths_per_million': Decimal('953'),
#   'population': Decimal('3983409')},
#  {'country': 'Nepal',
#   'confirmed': 277640,
#   'new_cases': 179,
#   'deaths': 3031,
#   'recovered': 272962,
#   'active': 1647,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 2279105,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('9403'),
#   'total_deaths_per_million': Decimal('103'),
#   'population': Decimal('29527704')},
#  {'country': 'Croatia',
#   'confirmed': 276416,
#   'new_cases': 2362,
#   'deaths': 5996,
#   'recovered': 257309,
#   'active': 13111,
#   'critical': 153,
#   'new_deaths': 29,
#   'total_tests': 1568027,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('67646'),
#   'total_deaths_per_million': Decimal('1467'),
#   'population': Decimal('4086201')},
#  {'country': 'Bolivia',
#   'confirmed': 273327,
#   'new_cases': 916,
#   'deaths': 12280,
#   'recovered': 222924,
#   'active': 38123,
#   'critical': 71,
#   'new_deaths': 23,
#   'total_tests': 915509,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('23179'),
#   'total_deaths_per_million': Decimal('1041'),
#   'population': Decimal('11792020')},
#  {'country': 'Greece',
#   'confirmed': 267172,
#   'new_cases': 0,
#   'deaths': 8160,
#   'recovered': 227518,
#   'active': 31494,
#   'critical': 755,
#   'new_deaths': 0,
#   'total_tests': 6589204,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('25727'),
#   'total_deaths_per_million': Decimal('786'),
#   'population': Decimal('10384729')},
#  {'country': 'Azerbaijan',
#   'confirmed': 263961,
#   'new_cases': 0,
#   'deaths': 3593,
#   'recovered': 238985,
#   'active': 21383,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 2888033,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('25859'),
#   'total_deaths_per_million': Decimal('352'),
#   'population': Decimal('10207610')},
#  {'country': 'Tunisia',
#   'confirmed': 255308,
#   'new_cases': 0,
#   'deaths': 8843,
#   'recovered': 217928,
#   'active': 28537,
#   'critical': 325,
#   'new_deaths': 0,
#   'total_tests': 1115541,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('21434'),
#   'total_deaths_per_million': Decimal('742'),
#   'population': Decimal('11911166')},
#  {'country': 'Dominican Republic',
#   'confirmed': 253196,
#   'new_cases': 0,
#   'deaths': 3330,
#   'recovered': 212818,
#   'active': 37048,
#   'critical': 154,
#   'new_deaths': 0,
#   'total_tests': 1311788,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('23167'),
#   'total_deaths_per_million': Decimal('305'),
#   'population': Decimal('10929334')},
#  {'country': 'Kazakhstan',
#   'confirmed': 248931,
#   'new_cases': 2077,
#   'deaths': 3072,
#   'recovered': 221347,
#   'active': 24512,
#   'critical': 221,
#   'new_deaths': 12,
#   'total_tests': 8669927,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('13140'),
#   'total_deaths_per_million': Decimal('162'),
#   'population': Decimal('18944679')},
#  {'country': 'Palestine',
#   'confirmed': 244645,
#   'new_cases': 0,
#   'deaths': 2645,
#   'recovered': 217224,
#   'active': 24776,
#   'critical': 197,
#   'new_deaths': 0,
#   'total_tests': 1548704,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('47141'),
#   'total_deaths_per_million': Decimal('510'),
#   'population': Decimal('5189658')},
#  {'country': 'Ireland',
#   'confirmed': 236600,
#   'new_cases': 0,
#   'deaths': 4705,
#   'recovered': 23364,
#   'active': 208531,
#   'critical': 63,
#   'new_deaths': 0,
#   'total_tests': 4025669,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('47519'),
#   'total_deaths_per_million': Decimal('945'),
#   'population': Decimal('4979051')},
#  {'country': 'Kuwait',
#   'confirmed': 233521,
#   'new_cases': 0,
#   'deaths': 1319,
#   'recovered': 217873,
#   'active': 14329,
#   'critical': 252,
#   'new_deaths': 0,
#   'total_tests': 2066048,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('54084'),
#   'total_deaths_per_million': Decimal('305'),
#   'population': Decimal('4317748')},
#  {'country': 'Denmark',
#   'confirmed': 231973,
#   'new_cases': 708,
#   'deaths': 2424,
#   'recovered': 220354,
#   'active': 9195,
#   'critical': 41,
#   'new_deaths': 1,
#   'total_tests': 25996859,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('39944'),
#   'total_deaths_per_million': Decimal('417'),
#   'population': Decimal('5807509')},
#  {'country': 'Moldova',
#   'confirmed': 231756,
#   'new_cases': 0,
#   'deaths': 5003,
#   'recovered': 209907,
#   'active': 16846,
#   'critical': 331,
#   'new_deaths': 0,
#   'total_tests': 853345,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('57552'),
#   'total_deaths_per_million': Decimal('1242'),
#   'population': Decimal('4026912')},
#  {'country': 'Slovenia',
#   'confirmed': 218114,
#   'new_cases': 1169,
#   'deaths': 4063,
#   'recovered': 200422,
#   'active': 13629,
#   'critical': 118,
#   'new_deaths': 9,
#   'total_tests': 1069681,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('104905'),
#   'total_deaths_per_million': Decimal('1954'),
#   'population': Decimal('2079153')},
#  {'country': 'Lithuania',
#   'confirmed': 217865,
#   'new_cases': 810,
#   'deaths': 3594,
#   'recovered': 200266,
#   'active': 14005,
#   'critical': 139,
#   'new_deaths': 10,
#   'total_tests': 2382096,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('80882'),
#   'total_deaths_per_million': Decimal('1334'),
#   'population': Decimal('2693609')},
#  {'country': 'Costa Rica',
#   'confirmed': 216764,
#   'new_cases': 0,
#   'deaths': 2957,
#   'recovered': 192699,
#   'active': 21108,
#   'critical': 163,
#   'new_deaths': 0,
#   'total_tests': 811544,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('42263'),
#   'total_deaths_per_million': Decimal('577'),
#   'population': Decimal('5128949')},
#  {'country': 'Paraguay',
#   'confirmed': 216278,
#   'new_cases': 0,
#   'deaths': 4250,
#   'recovered': 177202,
#   'active': 34826,
#   'critical': 428,
#   'new_deaths': 0,
#   'total_tests': 918743,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('30047'),
#   'total_deaths_per_million': Decimal('590'),
#   'population': Decimal('7198054')},
#  {'country': 'Ethiopia',
#   'confirmed': 208961,
#   'new_cases': 0,
#   'deaths': 2890,
#   'recovered': 159436,
#   'active': 46635,
#   'critical': 853,
#   'new_deaths': 0,
#   'total_tests': 2365187,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1785'),
#   'total_deaths_per_million': Decimal('25'),
#   'population': Decimal('117081085')},
#  {'country': 'Egypt',
#   'confirmed': 202843,
#   'new_cases': 0,
#   'deaths': 12041,
#   'recovered': 155016,
#   'active': 35786,
#   'critical': 90,
#   'new_deaths': 0,
#   'total_tests': 2506788,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1955'),
#   'total_deaths_per_million': Decimal('116'),
#   'population': Decimal('103773526')},
#  {'country': 'Armenia',
#   'confirmed': 194852,
#   'new_cases': 1116,
#   'deaths': 3552,
#   'recovered': 174545,
#   'active': 16755,
#   'critical': 0,
#   'new_deaths': 19,
#   'total_tests': 864876,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('65664'),
#   'total_deaths_per_million': Decimal('1197'),
#   'population': Decimal('2967402')},
#  {'country': 'Guatemala',
#   'confirmed': 194756,
#   'new_cases': 0,
#   'deaths': 6860,
#   'recovered': 177964,
#   'active': 9932,
#   'critical': 5,
#   'new_deaths': 0,
#   'total_tests': 1052595,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('10723'),
#   'total_deaths_per_million': Decimal('378'),
#   'population': Decimal('18162709')},
#  {'country': 'Honduras',
#   'confirmed': 189726,
#   'new_cases': 683,
#   'deaths': 4622,
#   'recovered': 73308,
#   'active': 111796,
#   'critical': 468,
#   'new_deaths': 17,
#   'total_tests': 519992,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('18931'),
#   'total_deaths_per_million': Decimal('461'),
#   'population': Decimal('10022219')},
#  {'country': 'Qatar',
#   'confirmed': 180804,
#   'new_cases': 0,
#   'deaths': 295,
#   'recovered': 164544,
#   'active': 15965,
#   'critical': 358,
#   'new_deaths': 0,
#   'total_tests': 1741631,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('64393'),
#   'total_deaths_per_million': Decimal('105'),
#   'population': Decimal('2807805')},
#  {'country': 'Bosnia and Herzegovina',
#   'confirmed': 171324,
#   'new_cases': 0,
#   'deaths': 6675,
#   'recovered': 131166,
#   'active': 33483,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 796448,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('52466'),
#   'total_deaths_per_million': Decimal('2044'),
#   'population': Decimal('3265450')},
#  {'country': 'Nigeria',
#   'confirmed': 162997,
#   'new_cases': 0,
#   'deaths': 2058,
#   'recovered': 151708,
#   'active': 9231,
#   'critical': 11,
#   'new_deaths': 0,
#   'total_tests': 1767694,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('776'),
#   'total_deaths_per_million': Decimal('10'),
#   'population': Decimal('209938714')},
#  {'country': 'Venezuela',
#   'confirmed': 161751,
#   'new_cases': 0,
#   'deaths': 1615,
#   'recovered': 148656,
#   'active': 11480,
#   'critical': 198,
#   'new_deaths': 0,
#   'total_tests': 3359014,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('5700'),
#   'total_deaths_per_million': Decimal('57'),
#   'population': Decimal('28375334')},
#  {'country': 'Libya',
#   'confirmed': 161088,
#   'new_cases': 1108,
#   'deaths': 2684,
#   'recovered': 148288,
#   'active': 10116,
#   'critical': 0,
#   'new_deaths': 4,
#   'total_tests': 871524,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('23208'),
#   'total_deaths_per_million': Decimal('387'),
#   'population': Decimal('6941123')},
#  {'country': 'Oman',
#   'confirmed': 160018,
#   'new_cases': 0,
#   'deaths': 1681,
#   'recovered': 144639,
#   'active': 13698,
#   'critical': 160,
#   'new_deaths': 0,
#   'total_tests': 1550000,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('30754'),
#   'total_deaths_per_million': Decimal('323'),
#   'population': Decimal('5203170')},
#  {'country': 'Bahrain',
#   'confirmed': 145380,
#   'new_cases': 0,
#   'deaths': 523,
#   'recovered': 136064,
#   'active': 8793,
#   'critical': 61,
#   'new_deaths': 0,
#   'total_tests': 3598553,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('83296'),
#   'total_deaths_per_million': Decimal('300'),
#   'population': Decimal('1745349')},
#  {'country': 'Myanmar',
#   'confirmed': 142466,
#   'new_cases': 0,
#   'deaths': 3206,
#   'recovered': 131802,
#   'active': 7458,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 2539586,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2605'),
#   'total_deaths_per_million': Decimal('59'),
#   'population': Decimal('54683190')},
#  {'country': 'Kenya',
#   'confirmed': 135042,
#   'new_cases': 0,
#   'deaths': 2167,
#   'recovered': 93067,
#   'active': 39808,
#   'critical': 153,
#   'new_deaths': 0,
#   'total_tests': 1494777,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2471'),
#   'total_deaths_per_million': Decimal('40'),
#   'population': Decimal('54653147')},
#  {'country': 'North Macedonia',
#   'confirmed': 131424,
#   'new_cases': 0,
#   'deaths': 3810,
#   'recovered': 107740,
#   'active': 19874,
#   'critical': 124,
#   'new_deaths': 0,
#   'total_tests': 629233,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('63084'),
#   'total_deaths_per_million': Decimal('1829'),
#   'population': Decimal('2083310')},
#  {'country': 'Albania',
#   'confirmed': 125506,
#   'new_cases': 0,
#   'deaths': 2241,
#   'recovered': 91875,
#   'active': 31390,
#   'critical': 18,
#   'new_deaths': 0,
#   'total_tests': 557421,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('43648'),
#   'total_deaths_per_million': Decimal('779'),
#   'population': Decimal('2875435')},
#  {'country': 'Algeria',
#   'confirmed': 117304,
#   'new_cases': 0,
#   'deaths': 3096,
#   'recovered': 81632,
#   'active': 32576,
#   'critical': 14,
#   'new_deaths': 0,
#   'total_tests': 230861,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2640'),
#   'total_deaths_per_million': Decimal('70'),
#   'population': Decimal('44441661')},
#  {'country': 'Estonia',
#   'confirmed': 108418,
#   'new_cases': 901,
#   'deaths': 922,
#   'recovered': 85053,
#   'active': 22443,
#   'critical': 72,
#   'new_deaths': 14,
#   'total_tests': 1155647,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('81689'),
#   'total_deaths_per_million': Decimal('695'),
#   'population': Decimal('1327205')},
#  {'country': 'Uruguay',
#   'confirmed': 108188,
#   'new_cases': 0,
#   'deaths': 1009,
#   'recovered': 85200,
#   'active': 21979,
#   'critical': 360,
#   'new_deaths': 0,
#   'total_tests': 1387452,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('31064'),
#   'total_deaths_per_million': Decimal('290'),
#   'population': Decimal('3482765')},
#  {'country': 'S. Korea',
#   'confirmed': 104194,
#   'new_cases': 555,
#   'deaths': 1737,
#   'recovered': 95861,
#   'active': 6596,
#   'critical': 101,
#   'new_deaths': 2,
#   'total_tests': 7788295,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2031'),
#   'total_deaths_per_million': Decimal('34'),
#   'population': Decimal('51302330')},
#  {'country': 'Latvia',
#   'confirmed': 103588,
#   'new_cases': 587,
#   'deaths': 1922,
#   'recovered': 94101,
#   'active': 7565,
#   'critical': 77,
#   'new_deaths': 9,
#   'total_tests': 1921360,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('55381'),
#   'total_deaths_per_million': Decimal('1028'),
#   'population': Decimal('1870467')},
#  {'country': 'Norway',
#   'confirmed': 96770,
#   'new_cases': 0,
#   'deaths': 673,
#   'recovered': 80023,
#   'active': 16074,
#   'critical': 61,
#   'new_deaths': 0,
#   'total_tests': 4687306,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('17746'),
#   'total_deaths_per_million': Decimal('123'),
#   'population': Decimal('5452999')},
#  {'country': 'Sri Lanka',
#   'confirmed': 92917,
#   'new_cases': 0,
#   'deaths': 571,
#   'recovered': 89407,
#   'active': 2939,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 2374627,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('4326'),
#   'total_deaths_per_million': Decimal('27'),
#   'population': Decimal('21480610')},
#  {'country': 'Montenegro',
#   'confirmed': 91573,
#   'new_cases': 0,
#   'deaths': 1286,
#   'recovered': 84035,
#   'active': 6252,
#   'critical': 69,
#   'new_deaths': 0,
#   'total_tests': 338243,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('145788'),
#   'total_deaths_per_million': Decimal('2047'),
#   'population': Decimal('628126')},
#  {'country': 'Ghana',
#   'confirmed': 90649,
#   'new_cases': 66,
#   'deaths': 744,
#   'recovered': 88159,
#   'active': 1746,
#   'critical': 39,
#   'new_deaths': 1,
#   'total_tests': 1001526,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2873'),
#   'total_deaths_per_million': Decimal('24'),
#   'population': Decimal('31556111')},
#  {'country': 'Zambia',
#   'confirmed': 88730,
#   'new_cases': 181,
#   'deaths': 1215,
#   'recovered': 84825,
#   'active': 2690,
#   'critical': 80,
#   'new_deaths': 3,
#   'total_tests': 1262291,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('4728'),
#   'total_deaths_per_million': Decimal('65'),
#   'population': Decimal('18766221')},
#  {'country': 'Kyrgyzstan',
#   'confirmed': 88700,
#   'new_cases': 162,
#   'deaths': 1500,
#   'recovered': 84979,
#   'active': 2221,
#   'critical': 24,
#   'new_deaths': 0,
#   'total_tests': 862010,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('13430'),
#   'total_deaths_per_million': Decimal('227'),
#   'population': Decimal('6604537')},
#  {'country': 'Uzbekistan',
#   'confirmed': 83239,
#   'new_cases': 189,
#   'deaths': 630,
#   'recovered': 81303,
#   'active': 1306,
#   'critical': 23,
#   'new_deaths': 0,
#   'total_tests': 1377915,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2460'),
#   'total_deaths_per_million': Decimal('19'),
#   'population': Decimal('33831575')},
#  {'country': 'Finland',
#   'confirmed': 78672,
#   'new_cases': 566,
#   'deaths': 846,
#   'recovered': 46000,
#   'active': 31826,
#   'critical': 52,
#   'new_deaths': 0,
#   'total_tests': 4011652,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('14182'),
#   'total_deaths_per_million': Decimal('153'),
#   'population': Decimal('5547184')},
#  {'country': 'Cuba',
#   'confirmed': 76276,
#   'new_cases': 0,
#   'deaths': 425,
#   'recovered': 71493,
#   'active': 4358,
#   'critical': 74,
#   'new_deaths': 0,
#   'total_tests': 2984264,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('6737'),
#   'total_deaths_per_million': Decimal('38'),
#   'population': Decimal('11321420')},
#  {'country': 'Mozambique',
#   'confirmed': 67729,
#   'new_cases': 0,
#   'deaths': 775,
#   'recovered': 56835,
#   'active': 10119,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 482221,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2123'),
#   'total_deaths_per_million': Decimal('24'),
#   'population': Decimal('31905591')},
#  {'country': 'El Salvador',
#   'confirmed': 64431,
#   'new_cases': 0,
#   'deaths': 2017,
#   'recovered': 61640,
#   'active': 774,
#   'critical': 30,
#   'new_deaths': 0,
#   'total_tests': 839408,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('9896'),
#   'total_deaths_per_million': Decimal('310'),
#   'population': Decimal('6510751')},
#  {'country': 'Luxembourg',
#   'confirmed': 61881,
#   'new_cases': 0,
#   'deaths': 749,
#   'recovered': 57366,
#   'active': 3766,
#   'critical': 30,
#   'new_deaths': 0,
#   'total_tests': 2411839,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('97669'),
#   'total_deaths_per_million': Decimal('1182'),
#   'population': Decimal('633580')},
#  {'country': 'Singapore',
#   'confirmed': 60450,
#   'new_cases': 43,
#   'deaths': 30,
#   'recovered': 60161,
#   'active': 259,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 8546349,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('10272'),
#   'total_deaths_per_million': Decimal('5'),
#   'population': Decimal('5884812')},
#  {'country': 'Cameroon',
#   'confirmed': 57337,
#   'new_cases': 0,
#   'deaths': 851,
#   'recovered': 51769,
#   'active': 4717,
#   'critical': 53,
#   'new_deaths': 0,
#   'total_tests': 1187367,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2121'),
#   'total_deaths_per_million': Decimal('31'),
#   'population': Decimal('27037191')},
#  {'country': 'Afghanistan',
#   'confirmed': 56595,
#   'new_cases': 23,
#   'deaths': 2496,
#   'recovered': 51798,
#   'active': 2301,
#   'critical': 1120,
#   'new_deaths': 1,
#   'total_tests': 351598,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1430'),
#   'total_deaths_per_million': Decimal('63'),
#   'population': Decimal('39580937')},
#  {'country': 'Cyprus',
#   'confirmed': 46173,
#   'new_cases': 0,
#   'deaths': 260,
#   'recovered': 2057,
#   'active': 43856,
#   'critical': 46,
#   'new_deaths': 0,
#   'total_tests': 3349002,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('38035'),
#   'total_deaths_per_million': Decimal('214'),
#   'population': Decimal('1213945')},
#  {'country': 'Namibia',
#   'confirmed': 44374,
#   'new_cases': 0,
#   'deaths': 528,
#   'recovered': 41910,
#   'active': 1936,
#   'critical': 33,
#   'new_deaths': 0,
#   'total_tests': 349054,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('17231'),
#   'total_deaths_per_million': Decimal('205'),
#   'population': Decimal('2575226')},
#  {'country': 'Ivory Coast',
#   'confirmed': 43889,
#   'new_cases': 0,
#   'deaths': 244,
#   'recovered': 40254,
#   'active': 3391,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 519522,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1634'),
#   'total_deaths_per_million': Decimal('9'),
#   'population': Decimal('26863991')},
#  {'country': 'Uganda',
#   'confirmed': 40889,
#   'new_cases': 0,
#   'deaths': 335,
#   'recovered': 40452,
#   'active': 102,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 942737,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('873'),
#   'total_deaths_per_million': Decimal('7'),
#   'population': Decimal('46811736')},
#  {'country': 'Botswana',
#   'confirmed': 40878,
#   'new_cases': 0,
#   'deaths': 591,
#   'recovered': 36958,
#   'active': 3329,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 932633,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('17125'),
#   'total_deaths_per_million': Decimal('248'),
#   'population': Decimal('2387009')},
#  {'country': 'Jamaica',
#   'confirmed': 39543,
#   'new_cases': 0,
#   'deaths': 599,
#   'recovered': 17725,
#   'active': 21219,
#   'critical': 52,
#   'new_deaths': 0,
#   'total_tests': 283592,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('13310'),
#   'total_deaths_per_million': Decimal('202'),
#   'population': Decimal('2970863')},
#  {'country': 'Senegal',
#   'confirmed': 38889,
#   'new_cases': 107,
#   'deaths': 1056,
#   'recovered': 37532,
#   'active': 301,
#   'critical': 34,
#   'new_deaths': 2,
#   'total_tests': 441464,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2278'),
#   'total_deaths_per_million': Decimal('62'),
#   'population': Decimal('17071787')},
#  {'country': 'Zimbabwe',
#   'confirmed': 36896,
#   'new_cases': 0,
#   'deaths': 1523,
#   'recovered': 34698,
#   'active': 675,
#   'critical': 13,
#   'new_deaths': 0,
#   'total_tests': 382999,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2456'),
#   'total_deaths_per_million': Decimal('101'),
#   'population': Decimal('15024557')},
#  {'country': 'Malawi',
#   'confirmed': 33584,
#   'new_cases': 0,
#   'deaths': 1118,
#   'recovered': 30379,
#   'active': 2087,
#   'critical': 28,
#   'new_deaths': 0,
#   'total_tests': 219103,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1722'),
#   'total_deaths_per_million': Decimal('57'),
#   'population': Decimal('19497344')},
#  {'country': 'Sudan',
#   'confirmed': 30111,
#   'new_cases': 0,
#   'deaths': 2063,
#   'recovered': 24214,
#   'active': 3834,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 232965,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('675'),
#   'total_deaths_per_million': Decimal('46'),
#   'population': Decimal('44611057')},
#  {'country': 'Australia',
#   'confirmed': 29333,
#   'new_cases': 14,
#   'deaths': 909,
#   'recovered': 26290,
#   'active': 2134,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 15773762,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1140'),
#   'total_deaths_per_million': Decimal('35'),
#   'population': Decimal('25721193')},
#  {'country': 'Malta',
#   'confirmed': 29127,
#   'new_cases': 42,
#   'deaths': 395,
#   'recovered': 28045,
#   'active': 687,
#   'critical': 0,
#   'new_deaths': 1,
#   'total_tests': 813463,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('65835'),
#   'total_deaths_per_million': Decimal('893'),
#   'population': Decimal('442426')},
#  {'country': 'Thailand',
#   'confirmed': 28947,
#   'new_cases': 58,
#   'deaths': 94,
#   'recovered': 27606,
#   'active': 1247,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 8124896,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('414'),
#   'total_deaths_per_million': Decimal('1'),
#   'population': Decimal('69931468')},
#  {'country': 'DRC',
#   'confirmed': 28199,
#   'new_cases': 0,
#   'deaths': 745,
#   'recovered': 25508,
#   'active': 1946,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('308'),
#   'total_deaths_per_million': Decimal('8'),
#   'population': Decimal('91580756')},
#  {'country': 'Madagascar',
#   'confirmed': 24968,
#   'new_cases': 272,
#   'deaths': 444,
#   'recovered': 22300,
#   'active': 2224,
#   'critical': 246,
#   'new_deaths': 11,
#   'total_tests': 144795,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('885'),
#   'total_deaths_per_million': Decimal('16'),
#   'population': Decimal('28220133')},
#  {'country': 'Maldives',
#   'confirmed': 24379,
#   'new_cases': 0,
#   'deaths': 67,
#   'recovered': 21282,
#   'active': 3030,
#   'critical': 99,
#   'new_deaths': 0,
#   'total_tests': 653492,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('44516'),
#   'total_deaths_per_million': Decimal('122'),
#   'population': Decimal('547646')},
#  {'country': 'Angola',
#   'confirmed': 22399,
#   'new_cases': 0,
#   'deaths': 538,
#   'recovered': 20508,
#   'active': 1353,
#   'critical': 12,
#   'new_deaths': 0,
#   'total_tests': 420085,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('666'),
#   'total_deaths_per_million': Decimal('16'),
#   'population': Decimal('33624239')},
#  {'country': 'Rwanda',
#   'confirmed': 21918,
#   'new_cases': 0,
#   'deaths': 308,
#   'recovered': 20308,
#   'active': 1302,
#   'critical': 5,
#   'new_deaths': 0,
#   'total_tests': 1156698,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1662'),
#   'total_deaths_per_million': Decimal('23'),
#   'population': Decimal('13190960')},
#  {'country': 'Guinea',
#   'confirmed': 20228,
#   'new_cases': 145,
#   'deaths': 128,
#   'recovered': 16832,
#   'active': 3268,
#   'critical': 24,
#   'new_deaths': 1,
#   'total_tests': 408613,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1510'),
#   'total_deaths_per_million': Decimal('10'),
#   'population': Decimal('13397388')},
#  {'country': 'Gabon',
#   'confirmed': 19550,
#   'new_cases': 0,
#   'deaths': 118,
#   'recovered': 16609,
#   'active': 2823,
#   'critical': 24,
#   'new_deaths': 0,
#   'total_tests': 637354,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('8632'),
#   'total_deaths_per_million': Decimal('52'),
#   'population': Decimal('2264807')},
#  {'country': 'Mayotte',
#   'confirmed': 19408,
#   'new_cases': 0,
#   'deaths': 161,
#   'recovered': 2964,
#   'active': 16283,
#   'critical': 17,
#   'new_deaths': 0,
#   'total_tests': 151773,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('69886'),
#   'total_deaths_per_million': Decimal('580'),
#   'population': Decimal('277711')},
#  {'country': 'Syria',
#   'confirmed': 19039,
#   'new_cases': 0,
#   'deaths': 1274,
#   'recovered': 12855,
#   'active': 4910,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1069'),
#   'total_deaths_per_million': Decimal('72'),
#   'population': Decimal('17816853')},
#  {'country': 'French Polynesia',
#   'confirmed': 18633,
#   'new_cases': 0,
#   'deaths': 141,
#   'recovered': 4842,
#   'active': 13650,
#   'critical': 2,
#   'new_deaths': 0,
#   'total_tests': 26355,
# ...
#   'total_deaths_per_million': Decimal('0.4'),
#   'population': Decimal('97994405')},
#  {'country': 'Cambodia',
#   'confirmed': 2546,
#   'new_cases': 69,
#   'deaths': 16,
#   'recovered': 1256,
#   'active': 1274,
#   'critical': 0,
#   'new_deaths': 2,
#   'total_tests': 706590,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('151'),
#   'total_deaths_per_million': Decimal('0.9'),
#   'population': Decimal('16891872')},
#  {'country': 'New Zealand',
#   'confirmed': 2501,
#   'new_cases': 0,
#   'deaths': 26,
#   'recovered': 2408,
#   'active': 67,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 1902915,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('500'),
#   'total_deaths_per_million': Decimal('5'),
#   'population': Decimal('5002100')},
#  {'country': 'Turks and Caicos',
#   'confirmed': 2337,
#   'new_cases': 0,
#   'deaths': 17,
#   'recovered': 2268,
#   'active': 52,
#   'critical': 3,
#   'new_deaths': 0,
#   'total_tests': 29647,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('59758'),
#   'total_deaths_per_million': Decimal('435'),
#   'population': Decimal('39108')},
#  {'country': 'Monaco',
#   'confirmed': 2305,
#   'new_cases': 0,
#   'deaths': 28,
#   'recovered': 2128,
#   'active': 149,
#   'critical': 7,
#   'new_deaths': 0,
#   'total_tests': 51953,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('58428'),
#   'total_deaths_per_million': Decimal('710'),
#   'population': Decimal('39450')},
#  {'country': 'Sao Tome and Principe',
#   'confirmed': 2232,
#   'new_cases': 0,
#   'deaths': 34,
#   'recovered': 2108,
#   'active': 90,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 12109,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('10045'),
#   'total_deaths_per_million': Decimal('153'),
#   'population': Decimal('222194')},
#  {'country': 'Sint Maarten',
#   'confirmed': 2151,
#   'new_cases': 0,
#   'deaths': 27,
#   'recovered': 2083,
#   'active': 41,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 23608,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('49746'),
#   'total_deaths_per_million': Decimal('624'),
#   'population': Decimal('43240')},
#  {'country': 'Liberia',
#   'confirmed': 2042,
#   'new_cases': 0,
#   'deaths': 85,
#   'recovered': 1899,
#   'active': 58,
#   'critical': 2,
#   'new_deaths': 0,
#   'total_tests': 79684,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('397'),
#   'total_deaths_per_million': Decimal('17'),
#   'population': Decimal('5146127')},
#  {'country': 'St. Vincent Grenadines',
#   'confirmed': 1754,
#   'new_cases': 4,
#   'deaths': 10,
#   'recovered': 1614,
#   'active': 130,
#   'critical': 2,
#   'new_deaths': 0,
#   'total_tests': 41557,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('15773'),
#   'total_deaths_per_million': Decimal('90'),
#   'population': Decimal('111204')},
#  {'country': 'Saint Martin',
#   'confirmed': 1659,
#   'new_cases': 0,
#   'deaths': 12,
#   'recovered': 1399,
#   'active': 248,
#   'critical': 7,
#   'new_deaths': 0,
#   'total_tests': 23812,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('42367'),
#   'total_deaths_per_million': Decimal('306'),
#   'population': Decimal('39158')},
#  {'country': 'Isle of Man',
#   'confirmed': 1570,
#   'new_cases': 0,
#   'deaths': 29,
#   'recovered': 1247,
#   'active': 294,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 44761,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('18391'),
#   'total_deaths_per_million': Decimal('340'),
#   'population': Decimal('85370')},
#  {'country': 'Caribbean Netherlands',
#   'confirmed': 1411,
#   'new_cases': 0,
#   'deaths': 11,
#   'recovered': 1127,
#   'active': 273,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 9238,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('53435'),
#   'total_deaths_per_million': Decimal('417'),
#   'population': Decimal('26406')},
#  {'country': 'Bermuda',
#   'confirmed': 1292,
#   'new_cases': 0,
#   'deaths': 12,
#   'recovered': 743,
#   'active': 537,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 201799,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('20803'),
#   'total_deaths_per_million': Decimal('193'),
#   'population': Decimal('62105')},
#  {'country': 'Antigua and Barbuda',
#   'confirmed': 1152,
#   'new_cases': 5,
#   'deaths': 28,
#   'recovered': 858,
#   'active': 266,
#   'critical': 45,
#   'new_deaths': 0,
#   'total_tests': 16493,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('11691'),
#   'total_deaths_per_million': Decimal('284'),
#   'population': Decimal('98536')},
#  {'country': 'Mauritius',
#   'confirmed': 1071,
#   'new_cases': 32,
#   'deaths': 12,
#   'recovered': 688,
#   'active': 371,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 289552,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('841'),
#   'total_deaths_per_million': Decimal('9'),
#   'population': Decimal('1273353')},
#  {'country': 'Taiwan',
#   'confirmed': 1039,
#   'new_cases': 3,
#   'deaths': 10,
#   'recovered': 987,
#   'active': 42,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 484871,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('44'),
#   'total_deaths_per_million': Decimal('0.4'),
#   'population': Decimal('23849146')},
#  {'country': 'Bhutan',
#   'confirmed': 886,
#   'new_cases': 0,
#   'deaths': 1,
#   'recovered': 869,
#   'active': 16,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 586497,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1139'),
#   'total_deaths_per_million': Decimal('1'),
#   'population': Decimal('777965')},
#  {'country': 'St. Barth',
#   'confirmed': 775,
#   'new_cases': 0,
#   'deaths': 1,
#   'recovered': 462,
#   'active': 312,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 21651,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('78283'),
#   'total_deaths_per_million': Decimal('101'),
#   'population': Decimal('9900')},
#  {'country': 'Diamond Princess',
#   'confirmed': 712,
#   'new_cases': 0,
#   'deaths': 13,
#   'recovered': 699,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': 'Timor-Leste',
#   'confirmed': 677,
#   'new_cases': 34,
#   'deaths': 0,
#   'recovered': 216,
#   'active': 461,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 44090,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('506'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('1337167')},
#  {'country': 'Faeroe Islands',
#   'confirmed': 661,
#   'new_cases': 0,
#   'deaths': 1,
#   'recovered': 660,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 241762,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('13489'),
#   'total_deaths_per_million': Decimal('20'),
#   'population': Decimal('49002')},
#  {'country': 'Tanzania',
#   'confirmed': 509,
#   'new_cases': 0,
#   'deaths': 21,
#   'recovered': 183,
#   'active': 305,
#   'critical': 7,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('8'),
#   'total_deaths_per_million': Decimal('0.3'),
#   'population': Decimal('60997199')},
#  {'country': 'Cayman Islands',
#   'confirmed': 501,
#   'new_cases': 0,
#   'deaths': 2,
#   'recovered': 477,
#   'active': 22,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 82843,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('7557'),
#   'total_deaths_per_million': Decimal('30'),
#   'population': Decimal('66299')},
#  {'country': 'Wallis and Futuna',
#   'confirmed': 410,
#   'new_cases': 1,
#   'deaths': 4,
#   'recovered': 44,
#   'active': 362,
#   'critical': 4,
#   'new_deaths': 0,
#   'total_tests': 1331,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('36970'),
#   'total_deaths_per_million': Decimal('361'),
#   'population': Decimal('11090')},
#  {'country': 'Brunei',
#   'confirmed': 213,
#   'new_cases': 0,
#   'deaths': 3,
#   'recovered': 195,
#   'active': 15,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 114397,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('483'),
#   'total_deaths_per_million': Decimal('7'),
#   'population': Decimal('440615')},
#  {'country': 'Dominica',
#   'confirmed': 164,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 157,
#   'active': 7,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 13376,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2274'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('72120')},
#  {'country': 'Grenada',
#   'confirmed': 155,
#   'new_cases': 0,
#   'deaths': 1,
#   'recovered': 152,
#   'active': 2,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 23989,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1373'),
#   'total_deaths_per_million': Decimal('9'),
#   'population': Decimal('112914')},
#  {'country': 'British Virgin Islands',
#   'confirmed': 153,
#   'new_cases': 0,
#   'deaths': 1,
#   'recovered': 131,
#   'active': 21,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 13223,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('5036'),
#   'total_deaths_per_million': Decimal('33'),
#   'population': Decimal('30382')},
#  {'country': 'New Caledonia',
#   'confirmed': 121,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 58,
#   'active': 63,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 28685,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('421'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('287553')},
#  {'country': 'Fiji',
#   'confirmed': 67,
#   'new_cases': 0,
#   'deaths': 2,
#   'recovered': 64,
#   'active': 1,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 36597,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('74'),
#   'total_deaths_per_million': Decimal('2'),
#   'population': Decimal('901313')},
#  {'country': 'Falkland Islands',
#   'confirmed': 54,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 54,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 7125,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('15190'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('3555')},
#  {'country': 'Laos',
#   'confirmed': 49,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 46,
#   'active': 3,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 134742,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('7'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('7354431')},
#  {'country': 'Macao',
#   'confirmed': 48,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 48,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 4369,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('73'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('655950')},
#  {'country': 'Saint Kitts and Nevis',
#   'confirmed': 44,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 44,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 12381,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('823'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('53481')},
#  {'country': 'Greenland',
#   'confirmed': 31,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 31,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 20669,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('545'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('56844')},
#  {'country': 'Vatican City',
#   'confirmed': 27,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 15,
#   'active': 12,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('33624'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('803')},
#  {'country': 'Anguilla',
#   'confirmed': 25,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 22,
#   'active': 3,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 14579,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1655'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('15103')},
#  {'country': 'Saint Pierre Miquelon',
#   'confirmed': 24,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 24,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 5126,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('4157'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('5773')},
#  {'country': 'Montserrat',
#   'confirmed': 20,
#   'new_cases': 0,
#   'deaths': 1,
#   'recovered': 19,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 1313,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('4005'),
#   'total_deaths_per_million': Decimal('200'),
#   'population': Decimal('4994')},
#  {'country': 'Solomon Islands',
#   'confirmed': 19,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 18,
#   'active': 1,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 4500,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('27'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('699411')},
#  {'country': 'Western Sahara',
#   'confirmed': 10,
#   'new_cases': 0,
#   'deaths': 1,
#   'recovered': 8,
#   'active': 1,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('16'),
#   'total_deaths_per_million': Decimal('2'),
#   'population': Decimal('608261')},
#  {'country': 'MS Zaandam',
#   'confirmed': 9,
#   'new_cases': 0,
#   'deaths': 2,
#   'recovered': 7,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': 'Marshall Islands',
#   'confirmed': 4,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 4,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('67'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('59489')},
#  {'country': 'Samoa',
#   'confirmed': 3,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 2,
#   'active': 1,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('15'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('199402')},
#  {'country': 'Vanuatu',
#   'confirmed': 3,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 1,
#   'active': 2,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 470,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('10'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('312485')},
#  {'country': 'Micronesia',
#   'confirmed': 1,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 1,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('9'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('115925')},
#  {'country': 'China',
#   'confirmed': 90226,
#   'new_cases': 9,
#   'deaths': 4636,
#   'recovered': 85402,
#   'active': 188,
#   'critical': 2,
#   'new_deaths': 0,
#   'total_tests': 160000000,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('63'),
#   'total_deaths_per_million': Decimal('3'),
#   'population': Decimal('1439323776')}]

# %% [markdown]
# Get the covid-19 related information by country ID

# %%
egypt = covid.get_status_by_country_name("Egypt")
poland = covid.get_status_by_country_name("Poland")
russia = covid.get_status_by_country_name("Russia")
japan = covid.get_status_by_country_name("Japan")
philippines = covid.get_status_by_country_name("Philippines")

print(f'Stats for Egypt: \n{egypt}\n')
print(f'Stats for Poland: \n{poland}\n')
print(f'Stats for Russia: \n{russia}\n')
print(f'Stats for Japan: \n{japan}\n')
print(f'Stats for Philippines: \n{philippines}\n')
# Out:
# Stats for Egypt:
# {'country': 'Egypt', 'confirmed': 202843, 'new_cases': 0, 'deaths': 12041, 'recovered': 155016, 'active': 35786, 'critical': 90, 'new_deaths': 0, 'total_tests': 2506788, 'total_tests_per_million': Decimal('0'), 'total_cases_per_million': Decimal('1955'), 'total_deaths_per_million': Decimal('116'), 'population': Decimal('103773526')}
#
# Stats for Poland:
# {'country': 'Poland', 'confirmed': 2387511, 'new_cases': 30546, 'deaths': 54165, 'recovered': 1911249, 'active': 422097, 'critical': 3157, 'new_deaths': 497, 'total_tests': 12246907, 'total_tests_per_million': Decimal('0'), 'total_cases_per_million': Decimal('63136'), 'total_deaths_per_million': Decimal('1432'), 'population': Decimal('37815450')}
#
# Stats for Russia:
# {'country': 'Russia', 'confirmed': 4563056, 'new_cases': 8792, 'deaths': 99633, 'recovered': 4186251, 'active': 277172, 'critical': 2300, 'new_deaths': 400, 'total_tests': 120900000, 'total_tests_per_million': Decimal('0'), 'total_cases_per_million': Decimal('31258'), 'total_deaths_per_million': Decimal('683'), 'population': Decimal('145981477')}
#
# Stats for Japan:
# {'country': 'Japan', 'confirmed': 474773, 'new_cases': 0, 'deaths': 9162, 'recovered': 446416, 'active': 19195, 'critical': 380, 'new_deaths': 0, 'total_tests': 9873913, 'total_tests_per_million': Decimal('0'), 'total_cases_per_million': Decimal('3763'), 'total_deaths_per_million': Decimal('73'), 'population': Decimal('126185196')}
#
# Stats for Philippines:
# {'country': 'Philippines', 'confirmed': 771497, 'new_cases': 15310, 'deaths': 13320, 'recovered': 604368, 'active': 153809, 'critical': 785, 'new_deaths': 17, 'total_tests': 10249771, 'total_tests_per_million': Decimal('0'), 'total_cases_per_million': Decimal('6971'), 'total_deaths_per_million': Decimal('120'), 'population': Decimal('110671238')}

# %%
for k,v in egypt.items(): 
    print('{} : {}'.format(k,v))
# Out:
# country : Egypt
# confirmed : 202843
# new_cases : 0
# deaths : 12041
# recovered : 155016
# active : 35786
# critical : 90
# new_deaths : 0
# total_tests : 2506788
# total_tests_per_million : 0
# total_cases_per_million : 1955
# total_deaths_per_million : 116
# population : 103773526

# %%
for k,v in philippines.items(): 
    print('{} : {}'.format(k,v))
# Out:
# country : Philippines
# confirmed : 771497
# new_cases : 15310
# deaths : 13320
# recovered : 604368
# active : 153809
# critical : 785
# new_deaths : 17
# total_tests : 10249771
# total_tests_per_million : 0
# total_cases_per_million : 6971
# total_deaths_per_million : 120
# population : 110671238

# %%
active = covid.get_total_active_cases()
confirmed = covid.get_total_confirmed_cases()
recovered = covid.get_total_recovered()
deaths = covid.get_total_deaths()

# %%
print("Active    : ", active)
print("Confirmed : ", confirmed)
print("Recovered : ", recovered)
print("Deaths    : ", deaths)
# Out:
# Active    :  22480016
# Confirmed :  130327786
# Recovered :  105004996
# Deaths    :  2842774
